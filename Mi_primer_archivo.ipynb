# %%
import sklearn

# %%
print("Hello sklearn , ¿Para que sirves?")
# Out:
# Hello sklearn , ¿Para que sirves?

# %%
import tensorflow

# %%
from tensorflow import keras
print(keras.__version__)
# Out:
# 3.9.2
